# %% [markdown]
# <a href="https://colab.research.google.com/github/meetchovatiya46/Employee-Attrition/blob/main/Emplyee_Attrition_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ======================================
# Cell 1: Import Libraries
# ======================================

# Data Manipulation
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt

# Display Settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 10)

# %%
# ======================================
# Cell 2: Load Dataset
# ======================================

# Load Dataset
df = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")

print("✅ Dataset loaded successfully.")

# Display first five rows
df.head()
# Out:
# ✅ Dataset loaded successfully.
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
# ...

# %%
# ======================================
# Cell 3: Dataset Overview
# ======================================

print("="*50)
print("Dataset Shape")
print("="*50)
print(df.shape)

print("\n" + "="*50)
print("Column Names")
print("="*50)
print(df.columns)

print("\n" + "="*50)
print("Dataset Information")
print("="*50)

df.info()

print("\n" + "="*50)
print("Statistical Summary")
print("="*50)

display(df.describe())
# Out:
# ...
# Dataset Shape
# ...
# (1470, 35)
#
# ...
# Column Names
# ...
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')
#
# ...
# Dataset Information
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ...

# %%
# ======================================
# Cell 4: Data Quality Checks
# ======================================

print("="*50)
print("Missing Values")
print("="*50)

display(df.isnull().sum())

print("\n" + "="*50)
print("Duplicate Records")
print("="*50)

print(df.duplicated().sum())
# Out:
# ...
# Missing Values
# ...
# Age                        0
# Attrition                  0
# BusinessTravel             0
# DailyRate                  0
# Department                 0
#                           ..
# WorkLifeBalance            0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# Length: 35, dtype: int64
# ...
# Duplicate Records
# ...
# 0

# %%
# ======================================
# Cell 5: Target Variable Analysis
# ======================================

print("="*50)
print("Target Variable Distribution")
print("="*50)

display(df["Attrition"].value_counts())

print("\nPercentage Distribution")

display(round(df["Attrition"].value_counts(normalize=True) * 100,3))
# Out:
# ...
# Target Variable Distribution
# ...
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64
# Percentage Distribution
# Attrition
# No     83.878
# Yes    16.122
# Name: proportion, dtype: float64

# %%
# ======================================
# Cell 6: Constant Column Analysis
# ======================================

print("="*50)
print("Unique Values Per Column")
print("="*50)

display(df.nunique().sort_values())

print("\nEmployeeCount")
display(df["EmployeeCount"].value_counts())

print("\nStandardHours")
display(df["StandardHours"].value_counts())

print("\nOver18")
display(df["Over18"].value_counts())

print("\nEmployeeNumber (First 5 Values)")
display(df["EmployeeNumber"].head())
# Out:
# ...
# Unique Values Per Column
# ...
# EmployeeCount        1
# Over18               1
# StandardHours        1
# Attrition            2
# OverTime             2
#                   ...
# HourlyRate          71
# DailyRate          886
# MonthlyIncome     1349
# MonthlyRate       1427
# EmployeeNumber    1470
# Length: 35, dtype: int64
# EmployeeCount
# EmployeeCount
# 1    1470
# Name: count, dtype: int64
# StandardHours
# StandardHours
# 80    1470
# Name: count, dtype: int64
# Over18
# Over18
# Y    1470
# Name: count, dtype: int64
# EmployeeNumber (First 5 Values)
# 0    1
# 1    2
# 2    4
# 3    5
# 4    7
# Name: EmployeeNumber, dtype: int64

# %%
# ======================================
# Cell 7: Data Cleaning
# ======================================

# Remove unnecessary columns
df.drop(
    columns=[
        "EmployeeCount",
        "StandardHours",
        "Over18",
        "EmployeeNumber"
    ],
    inplace=True
)

print("✅ Unnecessary columns removed successfully.")

print("\nUpdated Shape")
print(df.shape)

print("\nRemaining Columns")
display(df.columns)
# Out:
# ✅ Unnecessary columns removed successfully.
#
# Updated Shape
# (1470, 31)
#
# Remaining Columns
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
# ======================================
# EDA
# Cell 8 : Import Visualization Library
# ======================================

import seaborn as sns

sns.set_style("whitegrid")

print("Visualization library imported successfully.")
# Out:
# Visualization library imported successfully.

# %%
# ======================================
# Cell 9 : Attrition Distribution
# ======================================

plt.figure(figsize=(6,4))

sns.countplot(data=df, x="Attrition")

plt.title("Employee Attrition Distribution")
plt.xlabel("Attrition")
plt.ylabel("Number of Employees")

plt.show()

# %%
## What is the age distribution of employees?

plt.figure(figsize=(8,5))

sns.histplot(df["Age"], bins=15, kde=True)

plt.title("Age Distribution")

plt.xlabel("Age")

plt.ylabel("Number of Employees")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(data=df, x="Attrition", y="Age")

plt.title("Age vs Employee Attrition")

plt.show()

# %%
# ======================================
# Cell 12 : Gender vs Attrition
# ======================================

plt.figure(figsize=(7,5))

ax = sns.countplot(
    data=df,
    x="Gender",
    hue="Attrition",
    palette="Set2"
)

plt.title("Gender vs Employee Attrition", fontsize=14)
plt.xlabel("Gender")
plt.ylabel("Number of Employees")

# Add value counts on bars
for container in ax.containers:
    ax.bar_label(container)

plt.legend(title="Attrition")

plt.show()


gender_attrition = (
    df.groupby("Gender")["Attrition"]
      .value_counts(normalize=True)
      .mul(100)
      # .rename("Percentage")
      .round(2)
)

display(gender_attrition)
# Out:
# Gender  Attrition
# Female  No           85.20
#         Yes          14.80
# Male    No           82.99
#         Yes          17.01
# Name: proportion, dtype: float64

# %%
# ======================================
# Cell 13 : Department vs Attrition
# ======================================

plt.figure(figsize=(8,5))

ax = sns.countplot(
    data=df,
    x="Department",
    hue="Attrition",
    palette="Set2"
)

plt.title("Department vs Employee Attrition", fontsize=14)
plt.xlabel("Department")
plt.ylabel("Number of Employees")

# Add value labels
for container in ax.containers:
    ax.bar_label(container)

plt.legend(title="Attrition")

plt.xticks(rotation=3)

plt.show()

# --------------------------------------
# Attrition Percentage by Department
# --------------------------------------

department_attrition = (
    df.groupby("Department")["Attrition"]
      .value_counts(normalize=True)
      .mul(100)
      .round(2)
)

display(department_attrition)
# Out:
# Department              Attrition
# Human Resources         No           80.95
#                         Yes          19.05
# Research & Development  No           86.16
#                         Yes          13.84
# Sales                   No           79.37
#                         Yes          20.63
# Name: proportion, dtype: float64

# %%
# ======================================
# Cell 14 : BusinessTravel vs Attrition
# ======================================

plt.figure(figsize=(8,5))

ax = sns.countplot(
    data=df,
    x="BusinessTravel",
    hue="Attrition",
    palette="Set2"
)

plt.title("Business Travel vs Employee Attrition", fontsize=14)
plt.xlabel("Business Travel")
plt.ylabel("Number of Employees")

# Add value labels
for container in ax.containers:
    ax.bar_label(container)

plt.legend(title="Attrition")

plt.show()

# --------------------------------------
# Attrition Percentage by Business Travel
# --------------------------------------

business_travel_attrition = (
    df.groupby("BusinessTravel")["Attrition"]
      .value_counts(normalize=True)
      .mul(100)
      .round(2)
)

display(business_travel_attrition)
# Out:
# BusinessTravel     Attrition
# Non-Travel         No           92.00
#                    Yes           8.00
# Travel_Frequently  No           75.09
#                    Yes          24.91
# Travel_Rarely      No           85.04
#                    Yes          14.96
# Name: proportion, dtype: float64

# %%
# ======================================
# Cell 15 : OverTime vs Attrition
# ======================================

plt.figure(figsize=(7,5))

ax = sns.countplot(
    data=df,
    x="OverTime",
    hue="Attrition",
    palette="Set2"
)

plt.title("OverTime vs Employee Attrition", fontsize=14)
plt.xlabel("OverTime")
plt.ylabel("Number of Employees")

# Add value labels
for container in ax.containers:
    ax.bar_label(container)

plt.legend(title="Attrition")

plt.show()

# --------------------------------------
# Attrition Percentage by OverTime
# --------------------------------------

overtime_attrition = (
    df.groupby("OverTime")["Attrition"]
      .value_counts(normalize=True)
      .mul(100)
      .round(2)
)

display(overtime_attrition)
# Out:
# OverTime  Attrition
# No        No           89.56
#           Yes          10.44
# Yes       No           69.47
#           Yes          30.53
# Name: proportion, dtype: float64

# %%
# ======================================
# Cell 16 : MonthlyIncome vs Attrition
# ======================================

plt.figure(figsize=(8,5))

sns.boxplot(
    data=df,
    x="Attrition",
    y="MonthlyIncome",
    palette="Set2"
)

plt.title("Monthly Income vs Employee Attrition", fontsize=14)
plt.xlabel("Attrition")
plt.ylabel("Monthly Income")

plt.show()

# --------------------------------------
# Monthly Income Statistics by Attrition
# --------------------------------------

income_summary = (
    df.groupby("Attrition")["MonthlyIncome"]
      .describe()
      .round(2)
)

display(income_summary)
# Out:
# /tmp/ipykernel_1574/1980569096.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
#             count     mean      std     min     25%     50%     75%      max
# Attrition
# No         1233.0  6832.74  4818.21  1051.0  3211.0  5204.0  8834.0  19999.0
# Yes         237.0  4787.09  3640.21  1009.0  2373.0  3202.0  5916.0  19859.0

# %%
# ======================================
# Cell 17 : JobRole vs Attrition
# ======================================

plt.figure(figsize=(14,6))

ax = sns.countplot(
    data=df,
    x="JobRole",
    hue="Attrition",
    palette="Set2"
)

plt.title("Job Role vs Employee Attrition", fontsize=14)
plt.xlabel("Job Role")
plt.ylabel("Number of Employees")

# Add value labels
for container in ax.containers:
    ax.bar_label(container)

plt.xticks(rotation=45)
plt.legend(title="Attrition")

plt.show()

# --------------------------------------
# Attrition Percentage by Job Role
# --------------------------------------

jobrole_attrition = (
    df.groupby("JobRole")["Attrition"]
      .value_counts(normalize=True)
      .mul(100)
      .round(2)
)

display(jobrole_attrition)
# Out:
# JobRole                    Attrition
# Healthcare Representative  No           93.13
#                            Yes           6.87
# Human Resources            No           76.92
#                            Yes          23.08
# Laboratory Technician      No           76.06
#                                         ...
# Research Scientist         Yes          16.10
# Sales Executive            No           82.52
#                            Yes          17.48
# Sales Representative       No           60.24
#                            Yes          39.76
# Name: proportion, Length: 18, dtype: float64

# %%
# ======================================
# Cell 18 : JobSatisfaction vs Attrition
# ======================================

plt.figure(figsize=(8,5))

ax = sns.countplot(
    data=df,
    x="JobSatisfaction",
    hue="Attrition",
    palette="Set2"
)

plt.title("Job Satisfaction vs Employee Attrition", fontsize=14)
plt.xlabel("Job Satisfaction Level")
plt.ylabel("Number of Employees")

# Add value labels
for container in ax.containers:
    ax.bar_label(container)

plt.legend(title="Attrition")

plt.show()

# --------------------------------------
# Attrition Percentage by Job Satisfaction
# --------------------------------------

job_satisfaction_attrition = (
    df.groupby("JobSatisfaction")["Attrition"]
      .value_counts(normalize=True)
      .mul(100)
      .round(2)
)

display(job_satisfaction_attrition)
# Out:
# JobSatisfaction  Attrition
# 1                No           77.16
#                  Yes          22.84
# 2                No           83.57
#                  Yes          16.43
# 3                No           83.48
#                  Yes          16.52
# 4                No           88.67
#                  Yes          11.33
# Name: proportion, dtype: float64

# %%
# ======================================
# Cell 19 : WorkLifeBalance vs Attrition
# ======================================

plt.figure(figsize=(8,5))

ax = sns.countplot(
    data=df,
    x="WorkLifeBalance",
    hue="Attrition",
    palette="Set2"
)

plt.title("Work-Life Balance vs Employee Attrition", fontsize=14)
plt.xlabel("Work-Life Balance")
plt.ylabel("Number of Employees")

# Add value labels
for container in ax.containers:
    ax.bar_label(container)

plt.legend(title="Attrition")

plt.show()

# --------------------------------------
# Attrition Percentage by Work-Life Balance
# --------------------------------------

worklife_attrition = (
    df.groupby("WorkLifeBalance")["Attrition"]
      .value_counts(normalize=True)
      .mul(100)
      .round(2)
)

display(worklife_attrition)
# Out:
# WorkLifeBalance  Attrition
# 1                No           68.75
#                  Yes          31.25
# 2                No           83.14
#                  Yes          16.86
# 3                No           85.78
#                  Yes          14.22
# 4                No           82.35
#                  Yes          17.65
# Name: proportion, dtype: float64

# %%
# ======================================
# Cell 20 : DistanceFromHome vs Attrition
# ======================================

plt.figure(figsize=(8,5))

sns.boxplot(
    data=df,
    x="Attrition",
    y="DistanceFromHome",
    palette="Set2"
)

plt.title("Distance From Home vs Employee Attrition", fontsize=14)
plt.xlabel("Attrition")
plt.ylabel("Distance From Home (km)")

plt.show()

# --------------------------------------
# Distance Summary by Attrition
# --------------------------------------

distance_summary = (
    df.groupby("Attrition")["DistanceFromHome"]
      .describe()
      .round(2)
)

display(distance_summary)
# Out:
# /tmp/ipykernel_1574/578643136.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
#             count   mean   std  min  25%  50%   75%   max
# Attrition
# No         1233.0   8.92  8.01  1.0  2.0  7.0  13.0  29.0
# Yes         237.0  10.63  8.45  1.0  3.0  9.0  17.0  29.0

# %%
# ======================================
# Cell 21 : YearsAtCompany vs Attrition
# ======================================

plt.figure(figsize=(8,5))

sns.boxplot(
    data=df,
    x="Attrition",
    y="YearsAtCompany",
    palette="Set2"
)

plt.title("Years at Company vs Employee Attrition", fontsize=14)
plt.xlabel("Attrition")
plt.ylabel("Years at Company")

plt.show()

# --------------------------------------
# Years at Company Summary by Attrition
# --------------------------------------

years_company_summary = (
    df.groupby("Attrition")["YearsAtCompany"]
      .describe()
      .round(2)
)

display(years_company_summary)
# Out:
# /tmp/ipykernel_1574/3491085778.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
#             count  mean   std  min  25%  50%   75%   max
# Attrition
# No         1233.0  7.37  6.10  0.0  3.0  6.0  10.0  37.0
# Yes         237.0  5.13  5.95  0.0  1.0  3.0   7.0  40.0

# %%
# ======================================
# Cell 22 : Correlation Heatmap
# ======================================

plt.figure(figsize=(18,12))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5
)

plt.title("Correlation Heatmap", fontsize=16)

plt.show()

# %%
# ======================================
# Cell 23 : Business Insights Summary
# ======================================

business_insights = [
    "1. The dataset contains 1,470 employees, with an attrition rate of approximately 16.12%.",

    "2. Gender does not appear to have a significant impact on employee attrition.",

    "3. Employees in the Sales and Human Resources departments experience higher attrition than those in Research & Development.",

    "4. Employees who travel frequently have a much higher attrition rate than employees who travel rarely or do not travel.",

    "5. Employees working overtime are nearly three times more likely to leave the company.",

    "6. Employees with lower monthly income are more likely to leave the organization.",

    "7. Sales Representatives have the highest attrition rate among all job roles, while Research Directors have the lowest.",

    "8. Low job satisfaction is associated with higher employee attrition.",

    "9. Employees reporting poor work-life balance have substantially higher attrition rates.",

    "10. Employees with fewer years at the company are more likely to leave than long-tenured employees."
]

print("=" * 70)
print("           BUSINESS INSIGHTS FROM EDA")
print("=" * 70)

for insight in business_insights:
    print(insight)
# Out:
# ...
#            BUSINESS INSIGHTS FROM EDA
# ...
# 1. The dataset contains 1,470 employees, with an attrition rate of approximately 16.12%.
# 2. Gender does not appear to have a significant impact on employee attrition.
# 3. Employees in the Sales and Human Resources departments experience higher attrition than those in Research & Development.
# 4. Employees who travel frequently have a much higher attrition rate than employees who travel rarely or do not travel.
# 5. Employees working overtime are nearly three times more likely to leave the company.
# 6. Employees with lower monthly income are more likely to leave the organization.
# 7. Sales Representatives have the highest attrition rate among all job roles, while Research Directors have the lowest.
# 8. Low job satisfaction is associated with higher employee attrition.
# 9. Employees reporting poor work-life balance have substantially higher attrition rates.
# ...

# %%
# ======================================
# Cell 24 : Feature Engineering
# ======================================

# Identify categorical columns
categorical_cols = df.select_dtypes(include="object").columns

# Identify numerical columns
numerical_cols = df.select_dtypes(exclude="object").columns

print("=" * 50)
print("Categorical Features")
print("=" * 50)
print(list(categorical_cols))

print("\nTotal:", len(categorical_cols))

print("\n" + "=" * 50)
print("Numerical Features")
print("=" * 50)
print(list(numerical_cols))

print("\nTotal:", len(numerical_cols))
# Out:
# ...
# Categorical Features
# ...
# ['Attrition', 'BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime']
#
# Total: 8
#
# ...
# Numerical Features
# ...
# ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']
#
# Total: 23

# %%
# ======================================
# Cell 25 : Encoding Categorical Features
# ======================================

from sklearn.preprocessing import LabelEncoder

# Create a copy of the dataset
df_encoded = df.copy()

# -----------------------------
# Binary Categorical Columns
# -----------------------------
binary_cols = [
    "Attrition",
    "Gender",
    "OverTime"
]

# Apply Label Encoding
le = LabelEncoder()

for col in binary_cols:
    df_encoded[col] = le.fit_transform(df_encoded[col])

# -----------------------------
# Multi-Class Categorical Columns
# -----------------------------
multi_cols = [
    "BusinessTravel",
    "Department",
    "EducationField",
    "JobRole",
    "MaritalStatus"
]

# Apply One-Hot Encoding
df_encoded = pd.get_dummies(
    df_encoded,
    columns=multi_cols,
    drop_first=True,
    dtype=int
)

print("Encoding Completed Successfully ✅")

print("\nNew Shape:", df_encoded.shape)

display(df_encoded.head())
# Out:
# Encoding Completed Successfully ✅
#
# New Shape: (1470, 45)
#    Age  Attrition  DailyRate  DistanceFromHome  Education  \
# 0   41          1       1102                 1          2
# 1   49          0        279                 8          1
# 2   37          1       1373                 2          2
# 3   33          0       1392                 3          4
# 4   27          0        591                 2          1
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2       0          94               3         2
# 1                        3       1          61               2         2
# 2                        4       1          92               2         1
# 3                        4       0          56               3         1
# 4                        1       1          40               3         1
#
#    JobSatisfaction  MonthlyIncome  MonthlyRate  NumCompaniesWorked  OverTime  \
# ...

# %%
# ======================================
# Cell 26 : Define Features (X) and Target (y)
# ======================================

# Independent Variables
X = df_encoded.drop(columns="Attrition")

# Target Variable
y = df_encoded["Attrition"]

print("Shape of X :", X.shape)
print("Shape of y :", y.shape)

print("\nFirst 5 rows of X")
display(X.head())

print("\nFirst 5 values of y")
display(y.head())
# Out:
# Shape of X : (1470, 44)
# Shape of y : (1470,)
#
# First 5 rows of X
#    Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0   41       1102                 1          2                        2
# 1   49        279                 8          1                        3
# 2   37       1373                 2          2                        4
# 3   33       1392                 3          4                        4
# 4   27        591                 2          1                        1
#
#    Gender  HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  \
# 0       0          94               3         2                4
# 1       1          61               2         2                2
# 2       1          92               2         1                3
# 3       0          56               3         1                3
# 4       1          40               3         1                2
#
#    MonthlyIncome  MonthlyRate  NumCompaniesWorked  OverTime  \
# ...

# %%
# ======================================
# Cell 27 : Train-Test Split
# ======================================

from sklearn.model_selection import train_test_split

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training Features Shape :", X_train.shape)
print("Testing Features Shape  :", X_test.shape)

print("\nTraining Target Shape :", y_train.shape)
print("Testing Target Shape  :", y_test.shape)
# Out:
# Training Features Shape : (1176, 44)
# Testing Features Shape  : (294, 44)
#
# Training Target Shape : (1176,)
# Testing Target Shape  : (294,)

# %%
# ======================================
# Cell 28 : Feature Scaling
# ======================================

from sklearn.preprocessing import StandardScaler

# Create the scaler
scaler = StandardScaler()

# Fit on training data and transform
X_train_scaled = scaler.fit_transform(X_train)

# Transform testing data
X_test_scaled = scaler.transform(X_test)

print("\nScaled Training Shape :", X_train_scaled.shape)
print("Scaled Testing Shape  :", X_test_scaled.shape)
# Out:
# Scaled Training Shape : (1176, 44)
# Scaled Testing Shape  : (294, 44)

# %%
# ======================================
# Cell 29 : Logistic Regression Model
# ======================================

from sklearn.linear_model import LogisticRegression

# Create the model
log_model = LogisticRegression(random_state=42)

# Train the model
log_model.fit(X_train_scaled, y_train)

print("✅ Logistic Regression Model Trained Successfully")
# Out:
# ✅ Logistic Regression Model Trained Successfully

# %%
# ======================================
# Cell 30 : Logistic Regression Evaluation
# ======================================

from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
    roc_auc_score,
    ConfusionMatrixDisplay
)

# Predictions
y_pred = log_model.predict(X_test_scaled)

# Prediction probabilities
y_prob = log_model.predict_proba(X_test_scaled)[:, 1]

# ----------------------------
# Accuracy
# ----------------------------
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy Score : {accuracy:.4f}")

# ----------------------------
# ROC-AUC Score
# ----------------------------
roc_auc = roc_auc_score(y_test, y_prob)
print(f"ROC-AUC Score : {roc_auc:.4f}")

# ----------------------------
# Classification Report
# ----------------------------
print("\nClassification Report\n")
print(classification_report(y_test, y_pred))

# ----------------------------
# Confusion Matrix
# ----------------------------
cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(confusion_matrix=cm).plot(cmap="Blues")

plt.title("Confusion Matrix - Logistic Regression")
plt.show()
# Out:
# Accuracy Score : 0.8605
# ROC-AUC Score : 0.8079
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92       247
#            1       0.62      0.34      0.44        47
#
#     accuracy                           0.86       294
#    macro avg       0.75      0.65      0.68       294
# weighted avg       0.84      0.86      0.84       294

# %%
# ======================================
# Cell 31 : Decision Tree Classifier
# ======================================

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
    roc_auc_score,
    ConfusionMatrixDisplay
)

# Create Decision Tree model
dt_model = DecisionTreeClassifier(random_state=42)

# Train the model
dt_model.fit(X_train, y_train)

# Predictions
y_pred_dt = dt_model.predict(X_test)
y_prob_dt = dt_model.predict_proba(X_test)[:, 1]

# Accuracy
accuracy = accuracy_score(y_test, y_pred_dt)
print(f"Accuracy Score : {accuracy:.4f}")

# ROC-AUC
roc_auc = roc_auc_score(y_test, y_prob_dt)
print(f"ROC-AUC Score : {roc_auc:.4f}")

# Classification Report
print("\nClassification Report\n")
print(classification_report(y_test, y_pred_dt))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_dt)

ConfusionMatrixDisplay(confusion_matrix=cm).plot(cmap="Greens")

plt.title("Confusion Matrix - Decision Tree")
plt.show()
# Out:
# Accuracy Score : 0.7585
# ROC-AUC Score : 0.5979
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85       247
#            1       0.29      0.36      0.32        47
#
#     accuracy                           0.76       294
#    macro avg       0.58      0.60      0.59       294
# weighted avg       0.78      0.76      0.77       294

# %%
# ======================================
# Cell 32 : Random Forest Classifier
# ======================================

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
    roc_auc_score,
    ConfusionMatrixDisplay
)

# Create Random Forest model
rf_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

# Train the model
rf_model.fit(X_train, y_train)

# Predictions
y_pred_rf = rf_model.predict(X_test)
y_prob_rf = rf_model.predict_proba(X_test)[:, 1]

# Accuracy
accuracy = accuracy_score(y_test, y_pred_rf)
print(f"Accuracy Score : {accuracy:.4f}")

# ROC-AUC
roc_auc = roc_auc_score(y_test, y_prob_rf)
print(f"ROC-AUC Score : {roc_auc:.4f}")

# Classification Report
print("\nClassification Report\n")
print(classification_report(y_test, y_pred_rf))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_rf)

ConfusionMatrixDisplay(confusion_matrix=cm).plot(cmap="Purples")

plt.title("Confusion Matrix - Random Forest")
plt.show()
# Out:
# Accuracy Score : 0.8265
# ROC-AUC Score : 0.7864
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.90       247
#            1       0.30      0.06      0.11        47
#
#     accuracy                           0.83       294
#    macro avg       0.57      0.52      0.50       294
# weighted avg       0.76      0.83      0.78       294

# %%
# ======================================
# Cell 33 : XGBoost Classifier
# ======================================

# Install XGBoost (Run only once in Colab)
# !pip install -q xgboost

from xgboost import XGBClassifier
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
    roc_auc_score,
    ConfusionMatrixDisplay
)

# Create XGBoost model
xgb_model = XGBClassifier(
    random_state=42,
    eval_metric="logloss"
)

# Train the model
xgb_model.fit(X_train, y_train)

# Predictions
y_pred_xgb = xgb_model.predict(X_test)
y_prob_xgb = xgb_model.predict_proba(X_test)[:, 1]

# Accuracy
accuracy = accuracy_score(y_test, y_pred_xgb)
print(f"Accuracy Score : {accuracy:.4f}")

# ROC-AUC
roc_auc = roc_auc_score(y_test, y_prob_xgb)
print(f"ROC-AUC Score : {roc_auc:.4f}")

# Classification Report
print("\nClassification Report\n")
print(classification_report(y_test, y_pred_xgb))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_xgb)

ConfusionMatrixDisplay(confusion_matrix=cm).plot(cmap="Oranges")

plt.title("Confusion Matrix - XGBoost")
plt.show()
# Out:
# Accuracy Score : 0.8605
# ROC-AUC Score : 0.7638
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92       247
#            1       0.65      0.28      0.39        47
#
#     accuracy                           0.86       294
#    macro avg       0.76      0.62      0.65       294
# weighted avg       0.84      0.86      0.84       294

# %%
# ======================================
# Cell 34 : Hyperparameter Tuning
# Random Forest
# ======================================

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# Parameter Grid
param_grid = {
    "n_estimators": [100, 200, 300],
    "max_depth": [5, 10, 15, None],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "class_weight": [None, "balanced"]
}

rf = RandomForestClassifier(random_state=42)

grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,
    scoring="f1",
    n_jobs=-1,
    verbose=1
)

grid_search.fit(X_train, y_train)

print("Best Parameters:")
print(grid_search.best_params_)

print("\nBest Cross Validation Score:")
print(grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# Best Parameters:
# {'class_weight': 'balanced', 'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 100}
#
# Best Cross Validation Score:
# 0.48824588912787065

# %%
# ======================================
# Cell 35 : Tuned Random Forest
# ======================================

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
    roc_auc_score,
    ConfusionMatrixDisplay
)

# Create Tuned Random Forest Model
best_rf = RandomForestClassifier(
    n_estimators=100,
    max_depth=5,
    min_samples_split=2,
    min_samples_leaf=2,
    class_weight="balanced",
    random_state=42
)

# Train Model
best_rf.fit(X_train, y_train)

# Predictions
y_pred_best = best_rf.predict(X_test)
y_prob_best = best_rf.predict_proba(X_test)[:, 1]

# Accuracy
accuracy = accuracy_score(y_test, y_pred_best)
print(f"Accuracy Score : {accuracy:.4f}")

# ROC-AUC
roc_auc = roc_auc_score(y_test, y_prob_best)
print(f"ROC-AUC Score : {roc_auc:.4f}")

# Classification Report
print("\nClassification Report\n")
print(classification_report(y_test, y_pred_best))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_best)

ConfusionMatrixDisplay(
    confusion_matrix=cm
).plot(cmap="Greens")

plt.title("Confusion Matrix - Tuned Random Forest")

plt.show()
# Out:
# Accuracy Score : 0.7959
# ROC-AUC Score : 0.7662
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88       247
#            1       0.38      0.45      0.41        47
#
#     accuracy                           0.80       294
#    macro avg       0.64      0.65      0.64       294
# weighted avg       0.81      0.80      0.80       294

# %%
# ======================================
# Cell 36 : Hyperparameter Tuning
# Logistic Regression
# ======================================

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# Parameter Grid
param_grid = {
    "C": [0.01, 0.1, 1, 10, 100],
    "penalty": ["l1", "l2"],
    "solver": ["liblinear"],
    "class_weight": [None, "balanced"]
}

grid_lr = GridSearchCV(
    estimator=LogisticRegression(random_state=42),
    param_grid=param_grid,
    scoring="f1",
    cv=5,
    n_jobs=-1,
    verbose=1
)

grid_lr.fit(X_train_scaled, y_train)

print("Best Parameters:")
print(grid_lr.best_params_)

print("\nBest Cross Validation Score:")
print(grid_lr.best_score_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Parameters:
# {'C': 1, 'class_weight': None, 'penalty': 'l1', 'solver': 'liblinear'}
#
# Best Cross Validation Score:
# 0.5554502929690482

# %%
# ======================================
# Cell 37 : Tuned Logistic Regression
# ======================================

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
    roc_auc_score,
    ConfusionMatrixDisplay
)

# Create Tuned Logistic Regression Model
best_lr = LogisticRegression(
    C=1,
    penalty="l1",
    solver="liblinear",
    class_weight=None,
    random_state=42
)

# Train Model
best_lr.fit(X_train_scaled, y_train)

# Predictions
y_pred_best_lr = best_lr.predict(X_test_scaled)
y_prob_best_lr = best_lr.predict_proba(X_test_scaled)[:, 1]

# Accuracy
accuracy = accuracy_score(y_test, y_pred_best_lr)
print(f"Accuracy Score : {accuracy:.4f}")

# ROC-AUC
roc_auc = roc_auc_score(y_test, y_prob_best_lr)
print(f"ROC-AUC Score : {roc_auc:.4f}")

# Classification Report
print("\nClassification Report\n")
print(classification_report(y_test, y_pred_best_lr))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_best_lr)

ConfusionMatrixDisplay(confusion_matrix=cm).plot(cmap="Blues")

plt.title("Confusion Matrix - Tuned Logistic Regression")

plt.show()
# Out:
# Accuracy Score : 0.8605
# ROC-AUC Score : 0.8091
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92       247
#            1       0.62      0.34      0.44        47
#
#     accuracy                           0.86       294
#    macro avg       0.75      0.65      0.68       294
# weighted avg       0.84      0.86      0.84       294

# %%
# ======================================
# Cell 38 : Final Model Comparison
# ======================================

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score
)

comparison = pd.DataFrame({

    "Model":[
        "Logistic Regression",
        "Tuned Logistic Regression",
        "Decision Tree",
        "Random Forest",
        "Tuned Random Forest",
        "XGBoost"
    ],

    "Accuracy":[
        accuracy_score(y_test,y_pred),
        accuracy_score(y_test,y_pred_best_lr),
        accuracy_score(y_test,y_pred_dt),
        accuracy_score(y_test,y_pred_rf),
        accuracy_score(y_test,y_pred_best),
        accuracy_score(y_test,y_pred_xgb)
    ],

    "Precision":[
        precision_score(y_test,y_pred),
        precision_score(y_test,y_pred_best_lr),
        precision_score(y_test,y_pred_dt),
        precision_score(y_test,y_pred_rf),
        precision_score(y_test,y_pred_best),
        precision_score(y_test,y_pred_xgb)
    ],

    "Recall":[
        recall_score(y_test,y_pred),
        recall_score(y_test,y_pred_best_lr),
        recall_score(y_test,y_pred_dt),
        recall_score(y_test,y_pred_rf),
        recall_score(y_test,y_pred_best),
        recall_score(y_test,y_pred_xgb)
    ],

    "F1 Score":[
        f1_score(y_test,y_pred),
        f1_score(y_test,y_pred_best_lr),
        f1_score(y_test,y_pred_dt),
        f1_score(y_test,y_pred_rf),
        f1_score(y_test,y_pred_best),
        f1_score(y_test,y_pred_xgb)
    ],

    "ROC-AUC":[
        roc_auc_score(y_test,y_prob),
        roc_auc_score(y_test,y_prob_best_lr),
        roc_auc_score(y_test,y_prob_dt),
        roc_auc_score(y_test,y_prob_rf),
        roc_auc_score(y_test,y_prob_best),
        roc_auc_score(y_test,y_prob_xgb)
    ]

})

comparison = comparison.round(3)

comparison = comparison.sort_values(
    by="ROC-AUC",
    ascending=False
).reset_index(drop=True)

display(comparison)
# Out:
#                        Model  Accuracy  Precision  Recall  F1 Score  ROC-AUC
# 0  Tuned Logistic Regression     0.861      0.615   0.340     0.438    0.809
# 1        Logistic Regression     0.861      0.615   0.340     0.438    0.808
# 2              Random Forest     0.827      0.300   0.064     0.105    0.786
# 3        Tuned Random Forest     0.796      0.382   0.447     0.412    0.766
# 4                    XGBoost     0.861      0.650   0.277     0.388    0.764
# 5              Decision Tree     0.759      0.293   0.362     0.324    0.598

# %%
# ======================================
# Cell 39 : Final Model Selection
# ======================================

print("Final Selected Model : Tuned Logistic Regression\n")

print("Reason for Selection:")

print("""
• Highest ROC-AUC Score
• Highest F1-Score for Attrition Prediction
• Good Precision and Recall Balance
• Stable Performance
• Easy to Interpret
• Easy to Deploy
""")
# Out:
# Final Selected Model : Tuned Logistic Regression
#
# Reason for Selection:
#
# • Highest ROC-AUC Score
# • Highest F1-Score for Attrition Prediction
# • Good Precision and Recall Balance
# • Stable Performance
# • Easy to Interpret
# • Easy to Deploy

# %%
# ======================================
# Cell 40 : Save Final Model
# ======================================

import pickle

# Save the final tuned Logistic Regression model
with open("employee_attrition_model.pkl", "wb") as file:
    pickle.dump(best_lr, file)

print("✅ Final model saved successfully!")
print("File Name : employee_attrition_model.pkl")
# Out:
# ✅ Final model saved successfully!
# File Name : employee_attrition_model.pkl

# %%
# ======================================
# Cell 41 : Save StandardScaler
# ======================================

import pickle

# Save the trained StandardScaler
with open("scaler.pkl", "wb") as file:
    pickle.dump(scaler, file)

print("✅ StandardScaler saved successfully!")
print("File Name : scaler.pkl")
# Out:
# ✅ StandardScaler saved successfully!
# File Name : scaler.pkl

# %%
print(list(X.columns))
# Out:
# ['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'BusinessTravel_Travel_Frequently', 'BusinessTravel_Travel_Rarely', 'Department_Research & Development', 'Department_Sales', 'EducationField_Life Sciences', 'EducationField_Marketing', 'EducationField_Medical', 'EducationField_Other', 'EducationField_Technical Degree', 'JobRole_Human Resources', 'JobRole_Laboratory Technician', 'JobRole_Manager', 'JobRole_Manufacturing Director', 'JobRole_Research Director', 'JobRole_Research Scientist', 'JobRole_Sales Executive', 'JobRole_Sales Representative', 'MaritalStatus_Married', 'Marit
# ...
